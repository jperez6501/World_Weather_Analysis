# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 742

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description =city_weather["weather"][0]["description"]
        
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | luderitz
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | barrow
# Processing Record 4 of Set 1 | longyearbyen
# Processing Record 5 of Set 1 | melfort
# Processing Record 6 of Set 1 | grindavik
# Processing Record 7 of Set 1 | kosa
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | kazalinsk
# City not found. Skipping...
# Processing Record 10 of Set 1 | leningradskiy
# Processing Record 11 of Set 1 | sao joao da barra
# Processing Record 12 of Set 1 | ambulu
# Processing Record 13 of Set 1 | tucumcari
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 1 | gidam
# Processing Record 17 of Set 1 | saskylakh
# Processing Record 18 of Set 1 | new norfolk
# Processing Record 19 of Set 1 | clyde river
# Processing Record 20 of Set 1 | albany
# Processing Record 21 of Set 1 | east london
# Processing Record 22 of Set 1 | ostrovnoy
# Processing Record 23 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 1 | lompoc
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | goedereede
# Processing Record 27 of Set 1 | cherskiy
# Processing Record 28 of Set 1 | riyadh
# Processing Record 29 of Set 1 | carnarvon
# Processing Record 30 of Set 1 | freeport
# Processing Record 31 of Set 1 | chumikan
# Processing Record 32 of Set 1 | anadyr
# Processing Record 33 of Set 1 | vao
# Processing Record 34 of Set 1 | atuona
# Processing Record 35 of Set 1 | qaanaaq
# Processing Record 36 of Set 1 | gondanglegi
# Processing Record 37 of Set 1 | saint-joseph
# Processing Record 38 of Set 1 | asosa
# Processing Record 39 of Set 1 | lagoa
# Processing Record 40 of Set 1 | turan
# Processing Record 41 of Set 1 | hobart
# Processing Record 42 of Set 1 | agbor
# Processing Record 43 of Set 1 | ponta do sol
# Processing Record 44 of Set 1 | ust-kut
# Processing Record 45 of Set 1 | bluff
# Processing Record 46 of Set 1 | gat
# Processing Record 47 of Set 1 | salalah
# Processing Record 48 of Set 1 | khatanga
# Processing Record 49 of Set 1 | mundo nuevo
# Processing Record 50 of Set 1 | jamestown
# Processing Record 1 of Set 2 | manggar
# Processing Record 2 of Set 2 | saint-augustin
# Processing Record 3 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 2 | hilo
# Processing Record 5 of Set 2 | alofi
# Processing Record 6 of Set 2 | burns lake
# Processing Record 7 of Set 2 | azar shahr
# City not found. Skipping...
# Processing Record 8 of Set 2 | front royal
# Processing Record 9 of Set 2 | san clemente
# Processing Record 10 of Set 2 | arraial do cabo
# Processing Record 11 of Set 2 | porangatu
# Processing Record 12 of Set 2 | bonavista
# Processing Record 13 of Set 2 | kyzyl-suu
# Processing Record 14 of Set 2 | husavik
# Processing Record 15 of Set 2 | dikson
# Processing Record 16 of Set 2 | puerto ayora
# Processing Record 17 of Set 2 | hovd
# Processing Record 18 of Set 2 | cape town
# Processing Record 19 of Set 2 | kosh-agach
# Processing Record 20 of Set 2 | muli
# Processing Record 21 of Set 2 | urucara
# Processing Record 22 of Set 2 | rantoul
# Processing Record 23 of Set 2 | port elizabeth
# Processing Record 24 of Set 2 | road town
# Processing Record 25 of Set 2 | mar del plata
# Processing Record 26 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 27 of Set 2 | norman wells
# Processing Record 28 of Set 2 | torbay
# Processing Record 29 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 2 | san lawrenz
# Processing Record 31 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 2 | mataura
# Processing Record 33 of Set 2 | enterprise
# Processing Record 34 of Set 2 | pinar del rio
# Processing Record 35 of Set 2 | nikolskoye
# Processing Record 36 of Set 2 | tarakan
# Processing Record 37 of Set 2 | birin
# Processing Record 38 of Set 2 | bardiyah
# Processing Record 39 of Set 2 | hanting
# Processing Record 40 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 2 | ginda
# Processing Record 42 of Set 2 | ingham
# Processing Record 43 of Set 2 | thompson
# Processing Record 44 of Set 2 | sidi bu zayd
# City not found. Skipping...
# Processing Record 45 of Set 2 | klaksvik
# Processing Record 46 of Set 2 | santa maria da vitoria
# Processing Record 47 of Set 2 | severo-kurilsk
# Processing Record 48 of Set 2 | phan thiet
# Processing Record 49 of Set 2 | gerash
# Processing Record 50 of Set 2 | phuthaditjhaba
# Processing Record 1 of Set 3 | tura
# Processing Record 2 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 3 | pevek
# Processing Record 4 of Set 3 | plettenberg bay
# Processing Record 5 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 3 | baracoa
# Processing Record 7 of Set 3 | penco
# Processing Record 8 of Set 3 | chiredzi
# Processing Record 9 of Set 3 | haines junction
# Processing Record 10 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 3 | hithadhoo
# Processing Record 12 of Set 3 | miri
# Processing Record 13 of Set 3 | krasnoselkup
# Processing Record 14 of Set 3 | korla
# Processing Record 15 of Set 3 | rock sound
# Processing Record 16 of Set 3 | chicama
# Processing Record 17 of Set 3 | vaini
# Processing Record 18 of Set 3 | awjilah
# Processing Record 19 of Set 3 | tuktoyaktuk
# Processing Record 20 of Set 3 | codrington
# Processing Record 21 of Set 3 | port alfred
# Processing Record 22 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 23 of Set 3 | iqaluit
# Processing Record 24 of Set 3 | chulman
# Processing Record 25 of Set 3 | litayen
# City not found. Skipping...
# Processing Record 26 of Set 3 | vila velha
# Processing Record 27 of Set 3 | shiyan
# Processing Record 28 of Set 3 | saravan
# Processing Record 29 of Set 3 | bilibino
# Processing Record 30 of Set 3 | hermanus
# Processing Record 31 of Set 3 | saldanha
# Processing Record 32 of Set 3 | avera
# Processing Record 33 of Set 3 | atambua
# Processing Record 34 of Set 3 | kapaa
# Processing Record 35 of Set 3 | magadi
# Processing Record 36 of Set 3 | beyneu
# Processing Record 37 of Set 3 | bredasdorp
# Processing Record 38 of Set 3 | los llanos de aridane
# Processing Record 39 of Set 3 | rocha
# Processing Record 40 of Set 3 | viedma
# Processing Record 41 of Set 3 | okhotsk
# Processing Record 42 of Set 3 | stromness
# Processing Record 43 of Set 3 | stornoway
# Processing Record 44 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 45 of Set 3 | bubaque
# Processing Record 46 of Set 3 | seoul
# Processing Record 47 of Set 3 | touros
# Processing Record 48 of Set 3 | college
# Processing Record 49 of Set 3 | bilma
# Processing Record 50 of Set 3 | saint george
# Processing Record 1 of Set 4 | katangli
# Processing Record 2 of Set 4 | rawson
# Processing Record 3 of Set 4 | tezu
# Processing Record 4 of Set 4 | astoria
# Processing Record 5 of Set 4 | yulara
# Processing Record 6 of Set 4 | pacifica
# Processing Record 7 of Set 4 | beaune
# Processing Record 8 of Set 4 | tasiilaq
# Processing Record 9 of Set 4 | duldurga
# Processing Record 10 of Set 4 | isangel
# Processing Record 11 of Set 4 | nouadhibou
# Processing Record 12 of Set 4 | kodiak
# Processing Record 13 of Set 4 | axim
# Processing Record 14 of Set 4 | airai
# Processing Record 15 of Set 4 | verkhovazhye
# Processing Record 16 of Set 4 | nikki
# Processing Record 17 of Set 4 | devils lake
# Processing Record 18 of Set 4 | lata
# Processing Record 19 of Set 4 | condado
# Processing Record 20 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 4 | kuito
# Processing Record 22 of Set 4 | yellowknife
# Processing Record 23 of Set 4 | malanje
# Processing Record 24 of Set 4 | lebu
# Processing Record 25 of Set 4 | timmins
# Processing Record 26 of Set 4 | bambous virieux
# Processing Record 27 of Set 4 | kaitangata
# Processing Record 28 of Set 4 | tamworth
# Processing Record 29 of Set 4 | yar-sale
# Processing Record 30 of Set 4 | christchurch
# Processing Record 31 of Set 4 | butaritari
# Processing Record 32 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 33 of Set 4 | guanay
# Processing Record 34 of Set 4 | vestmanna
# Processing Record 35 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 36 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 37 of Set 4 | huarmey
# Processing Record 38 of Set 4 | bandarbeyla
# Processing Record 39 of Set 4 | bonaventure
# Processing Record 40 of Set 4 | shenzhen
# Processing Record 41 of Set 4 | nioro
# Processing Record 42 of Set 4 | charagua
# Processing Record 43 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 4 | coquimbo
# Processing Record 45 of Set 4 | arlit
# Processing Record 46 of Set 4 | bonthe
# Processing Record 47 of Set 4 | kavieng
# Processing Record 48 of Set 4 | truth or consequences
# Processing Record 49 of Set 4 | sitka
# Processing Record 50 of Set 4 | achisay
# City not found. Skipping...
# Processing Record 1 of Set 5 | narsaq
# Processing Record 2 of Set 5 | samarai
# Processing Record 3 of Set 5 | avarua
# Processing Record 4 of Set 5 | aguada de pasajeros
# Processing Record 5 of Set 5 | tuatapere
# Processing Record 6 of Set 5 | lavrentiya
# Processing Record 7 of Set 5 | roshni-chu
# Processing Record 8 of Set 5 | oktyabrskaya
# City not found. Skipping...
# Processing Record 9 of Set 5 | yacuiba
# Processing Record 10 of Set 5 | castro
# Processing Record 11 of Set 5 | halifax
# Processing Record 12 of Set 5 | georgetown
# Processing Record 13 of Set 5 | najran
# Processing Record 14 of Set 5 | jasper
# Processing Record 15 of Set 5 | sao filipe
# Processing Record 16 of Set 5 | vilhena
# Processing Record 17 of Set 5 | elat
# Processing Record 18 of Set 5 | hailar
# Processing Record 19 of Set 5 | penzance
# Processing Record 20 of Set 5 | havoysund
# Processing Record 21 of Set 5 | slave lake
# Processing Record 22 of Set 5 | gazli
# Processing Record 23 of Set 5 | dongsheng
# Processing Record 24 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 25 of Set 5 | katsuura
# Processing Record 26 of Set 5 | portland
# Processing Record 27 of Set 5 | ostersund
# Processing Record 28 of Set 5 | cabo san lucas
# Processing Record 29 of Set 5 | cabadiangan
# Processing Record 30 of Set 5 | muscat
# Processing Record 31 of Set 5 | pailon
# Processing Record 32 of Set 5 | buala
# Processing Record 33 of Set 5 | bethel
# Processing Record 34 of Set 5 | yatou
# Processing Record 35 of Set 5 | aitape
# Processing Record 36 of Set 5 | upernavik
# Processing Record 37 of Set 5 | russell
# Processing Record 38 of Set 5 | komarno
# Processing Record 39 of Set 5 | turukhansk
# Processing Record 40 of Set 5 | barbar
# City not found. Skipping...
# Processing Record 41 of Set 5 | ayr
# Processing Record 42 of Set 5 | asau
# Processing Record 43 of Set 5 | morozovsk
# Processing Record 44 of Set 5 | dingle
# Processing Record 45 of Set 5 | ixtapa
# Processing Record 46 of Set 5 | berlevag
# Processing Record 47 of Set 5 | chuy
# Processing Record 48 of Set 5 | tiksi
# Processing Record 49 of Set 5 | nanortalik
# Processing Record 50 of Set 5 | geraldton
# Processing Record 1 of Set 6 | beroroha
# Processing Record 2 of Set 6 | rio grande
# Processing Record 3 of Set 6 | luwingu
# Processing Record 4 of Set 6 | provideniya
# Processing Record 5 of Set 6 | pasighat
# Processing Record 6 of Set 6 | redcar
# Processing Record 7 of Set 6 | montepuez
# Processing Record 8 of Set 6 | gogrial
# Processing Record 9 of Set 6 | fortuna
# Processing Record 10 of Set 6 | saint-philippe
# Processing Record 11 of Set 6 | porto torres
# Processing Record 12 of Set 6 | nome
# Processing Record 13 of Set 6 | sechura
# Processing Record 14 of Set 6 | namibe
# Processing Record 15 of Set 6 | tarauaca
# Processing Record 16 of Set 6 | kuala lipis
# Processing Record 17 of Set 6 | cap malheureux
# Processing Record 18 of Set 6 | nanfeng
# Processing Record 19 of Set 6 | rundu
# Processing Record 20 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 6 | sioux lookout
# Processing Record 22 of Set 6 | floriano
# Processing Record 23 of Set 6 | victoria
# Processing Record 24 of Set 6 | acarau
# Processing Record 25 of Set 6 | chongwe
# Processing Record 26 of Set 6 | pontes e lacerda
# Processing Record 27 of Set 6 | san cristobal
# Processing Record 28 of Set 6 | buchanan
# Processing Record 29 of Set 6 | kuching
# Processing Record 30 of Set 6 | uzice
# Processing Record 31 of Set 6 | koratla
# Processing Record 32 of Set 6 | cayenne
# Processing Record 33 of Set 6 | killam
# Processing Record 34 of Set 6 | caravelas
# Processing Record 35 of Set 6 | constantine
# Processing Record 36 of Set 6 | broome
# Processing Record 37 of Set 6 | bhainsdehi
# Processing Record 38 of Set 6 | auki
# Processing Record 39 of Set 6 | moroni
# Processing Record 40 of Set 6 | merauke
# Processing Record 41 of Set 6 | begunitsy
# Processing Record 42 of Set 6 | sembe
# Processing Record 43 of Set 6 | port-cartier
# Processing Record 44 of Set 6 | chapais
# Processing Record 45 of Set 6 | cockburn town
# Processing Record 46 of Set 6 | zhaozhou
# Processing Record 47 of Set 6 | esmeraldas
# Processing Record 48 of Set 6 | punta gorda
# Processing Record 49 of Set 6 | sungaipenuh
# Processing Record 50 of Set 6 | mahebourg
# Processing Record 1 of Set 7 | kudat
# Processing Record 2 of Set 7 | port lincoln
# Processing Record 3 of Set 7 | batagay
# Processing Record 4 of Set 7 | kruisfontein
# Processing Record 5 of Set 7 | san policarpo
# Processing Record 6 of Set 7 | vanavara
# Processing Record 7 of Set 7 | qaqortoq
# Processing Record 8 of Set 7 | moerai
# Processing Record 9 of Set 7 | yankton
# Processing Record 10 of Set 7 | kracheh
# City not found. Skipping...
# Processing Record 11 of Set 7 | tomatlan
# Processing Record 12 of Set 7 | aykhal
# Processing Record 13 of Set 7 | homer
# Processing Record 14 of Set 7 | strezhevoy
# Processing Record 15 of Set 7 | mnogovershinnyy
# Processing Record 16 of Set 7 | muscle shoals
# Processing Record 17 of Set 7 | jardim
# Processing Record 18 of Set 7 | tabou
# Processing Record 19 of Set 7 | ilhabela
# Processing Record 20 of Set 7 | odweyne
# Processing Record 21 of Set 7 | lugoba
# Processing Record 22 of Set 7 | manavalakurichi
# Processing Record 23 of Set 7 | tadine
# Processing Record 24 of Set 7 | emerald
# Processing Record 25 of Set 7 | ulladulla
# Processing Record 26 of Set 7 | meulaboh
# Processing Record 27 of Set 7 | kavaratti
# Processing Record 28 of Set 7 | faanui
# Processing Record 29 of Set 7 | mayumba
# Processing Record 30 of Set 7 | mecca
# Processing Record 31 of Set 7 | guerrero negro
# Processing Record 32 of Set 7 | derzhavinsk
# Processing Record 33 of Set 7 | awassa
# Processing Record 34 of Set 7 | bulawayo
# Processing Record 35 of Set 7 | yurginskoye
# Processing Record 36 of Set 7 | tawkar
# City not found. Skipping...
# Processing Record 37 of Set 7 | minuri
# Processing Record 38 of Set 7 | marzuq
# Processing Record 39 of Set 7 | marsh harbour
# Processing Record 40 of Set 7 | kirkland lake
# Processing Record 41 of Set 7 | esmeralda
# Processing Record 42 of Set 7 | lamu
# Processing Record 43 of Set 7 | zwedru
# Processing Record 44 of Set 7 | wolgast
# Processing Record 45 of Set 7 | luena
# Processing Record 46 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 47 of Set 7 | kirakira
# Processing Record 48 of Set 7 | taoudenni
# Processing Record 49 of Set 7 | konakovo
# Processing Record 50 of Set 7 | baruun-urt
# Processing Record 1 of Set 8 | mehamn
# Processing Record 2 of Set 8 | sapa
# Processing Record 3 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 4 of Set 8 | upington
# Processing Record 5 of Set 8 | pyay
# Processing Record 6 of Set 8 | kamphaeng phet
# Processing Record 7 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 8 of Set 8 | nuuk
# Processing Record 9 of Set 8 | hoquiam
# Processing Record 10 of Set 8 | aksarka
# Processing Record 11 of Set 8 | ancud
# Processing Record 12 of Set 8 | dharmadam
# Processing Record 13 of Set 8 | tual
# Processing Record 14 of Set 8 | grand gaube
# Processing Record 15 of Set 8 | linqing
# Processing Record 16 of Set 8 | taree
# Processing Record 17 of Set 8 | maneadero
# Processing Record 18 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 8 | shaartuz
# City not found. Skipping...
# Processing Record 20 of Set 8 | biankouma
# Processing Record 21 of Set 8 | ust-kuyga
# Processing Record 22 of Set 8 | guapore
# Processing Record 23 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 24 of Set 8 | sorland
# Processing Record 25 of Set 8 | puerto escondido
# Processing Record 26 of Set 8 | tucupita
# Processing Record 27 of Set 8 | chenzhou
# Processing Record 28 of Set 8 | oum hadjer
# Processing Record 29 of Set 8 | kacergine
# City not found. Skipping...
# Processing Record 30 of Set 8 | coihaique
# Processing Record 31 of Set 8 | jahrom
# City not found. Skipping...
# Processing Record 32 of Set 8 | vrede
# Processing Record 33 of Set 8 | ribeira grande
# Processing Record 34 of Set 8 | chokurdakh
# Processing Record 35 of Set 8 | talladega
# Processing Record 36 of Set 8 | kattivakkam
# Processing Record 37 of Set 8 | hasaki
# Processing Record 38 of Set 8 | khor
# Processing Record 39 of Set 8 | lebanon
# Processing Record 40 of Set 8 | pisco
# Processing Record 41 of Set 8 | mahanoro
# Processing Record 42 of Set 8 | lakes entrance
# Processing Record 43 of Set 8 | cochrane
# Processing Record 44 of Set 8 | ilula
# Processing Record 45 of Set 8 | maun
# Processing Record 46 of Set 8 | tshikapa
# Processing Record 47 of Set 8 | kiruna
# Processing Record 48 of Set 8 | ampanihy
# Processing Record 49 of Set 8 | flinders
# Processing Record 50 of Set 8 | naze
# Processing Record 1 of Set 9 | tutoia
# Processing Record 2 of Set 9 | lethem
# Processing Record 3 of Set 9 | oktyabrskoye
# Processing Record 4 of Set 9 | glossa
# Processing Record 5 of Set 9 | san patricio
# Processing Record 6 of Set 9 | praia da vitoria
# Processing Record 7 of Set 9 | el rosario
# Processing Record 8 of Set 9 | tonder
# Processing Record 9 of Set 9 | rio gallegos
# Processing Record 10 of Set 9 | porto belo
# Processing Record 11 of Set 9 | cidreira
# Processing Record 12 of Set 9 | tres arroyos
# Processing Record 13 of Set 9 | bay roberts
# Processing Record 14 of Set 9 | bengkulu
# Processing Record 15 of Set 9 | karanganyar
# Processing Record 16 of Set 9 | faya
# Processing Record 17 of Set 9 | kamenka
# Processing Record 18 of Set 9 | qui nhon
# Processing Record 19 of Set 9 | namatanai
# Processing Record 20 of Set 9 | ascension
# Processing Record 21 of Set 9 | piacabucu
# Processing Record 22 of Set 9 | yuxia
# Processing Record 23 of Set 9 | tempio pausania
# Processing Record 24 of Set 9 | sijunjung
# Processing Record 25 of Set 9 | luquillo
# Processing Record 26 of Set 9 | berdigestyakh
# Processing Record 27 of Set 9 | evensk
# Processing Record 28 of Set 9 | novobirilyussy
# Processing Record 29 of Set 9 | zhezkazgan
# Processing Record 30 of Set 9 | santa fe
# Processing Record 31 of Set 9 | yerbogachen
# Processing Record 32 of Set 9 | outlook
# Processing Record 33 of Set 9 | hauterive
# Processing Record 34 of Set 9 | sooke
# Processing Record 35 of Set 9 | mount isa
# Processing Record 36 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 37 of Set 9 | syracuse
# Processing Record 38 of Set 9 | dhanera
# Processing Record 39 of Set 9 | anloga
# Processing Record 40 of Set 9 | garissa
# Processing Record 41 of Set 9 | angoram
# Processing Record 42 of Set 9 | matara
# Processing Record 43 of Set 9 | ballstad
# City not found. Skipping...
# Processing Record 44 of Set 9 | chulucanas
# Processing Record 45 of Set 9 | san matias
# Processing Record 46 of Set 9 | vytegra
# Processing Record 47 of Set 9 | hunza
# City not found. Skipping...
# Processing Record 48 of Set 9 | beisfjord
# Processing Record 49 of Set 9 | atasu
# Processing Record 50 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 1 of Set 10 | adre
# Processing Record 2 of Set 10 | abu dhabi
# Processing Record 3 of Set 10 | hualmay
# Processing Record 4 of Set 10 | medicine hat
# Processing Record 5 of Set 10 | sidhauli
# Processing Record 6 of Set 10 | ahipara
# Processing Record 7 of Set 10 | aswan
# Processing Record 8 of Set 10 | sao jose da coroa grande
# Processing Record 9 of Set 10 | komsomolskiy
# Processing Record 10 of Set 10 | vikesa
# Processing Record 11 of Set 10 | gizo
# Processing Record 12 of Set 10 | erzin
# Processing Record 13 of Set 10 | cap-aux-meules
# Processing Record 14 of Set 10 | saint-paul
# Processing Record 15 of Set 10 | catuday
# Processing Record 16 of Set 10 | chiang khong
# Processing Record 17 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 18 of Set 10 | east bethel
# Processing Record 19 of Set 10 | baculin
# Processing Record 20 of Set 10 | yarada
# Processing Record 21 of Set 10 | vila franca do campo
# Processing Record 22 of Set 10 | maldonado
# Processing Record 23 of Set 10 | hue
# Processing Record 24 of Set 10 | port blair
# Processing Record 25 of Set 10 | riachao das neves
# Processing Record 26 of Set 10 | ola
# Processing Record 27 of Set 10 | hobyo
# Processing Record 28 of Set 10 | shalakusha
# Processing Record 29 of Set 10 | shaunavon
# Processing Record 30 of Set 10 | chanute
# Processing Record 31 of Set 10 | acari
# Processing Record 32 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 33 of Set 10 | khasan
# Processing Record 34 of Set 10 | mikhaylovka
# Processing Record 35 of Set 10 | sangar
# Processing Record 36 of Set 10 | corn island
# Processing Record 37 of Set 10 | ambon
# Processing Record 38 of Set 10 | makakilo city
# Processing Record 39 of Set 10 | yilan
# Processing Record 40 of Set 10 | chino valley
# Processing Record 41 of Set 10 | ovsyanka
# Processing Record 42 of Set 10 | nemuro
# Processing Record 43 of Set 10 | nchelenge
# Processing Record 44 of Set 10 | dabakala
# Processing Record 45 of Set 10 | san ramon de la nueva oran
# Processing Record 46 of Set 10 | beringovskiy
# Processing Record 47 of Set 10 | aklavik
# Processing Record 48 of Set 10 | inuvik
# Processing Record 49 of Set 10 | jumla
# Processing Record 50 of Set 10 | fairbanks
# Processing Record 1 of Set 11 | juneau
# Processing Record 2 of Set 11 | linxia
# Processing Record 3 of Set 11 | jiroft
# City not found. Skipping...
# Processing Record 4 of Set 11 | la ronge
# Processing Record 5 of Set 11 | manicore
# Processing Record 6 of Set 11 | lazaro cardenas
# Processing Record 7 of Set 11 | minsk
# Processing Record 8 of Set 11 | santana do mundau
# Processing Record 9 of Set 11 | adrar
# Processing Record 10 of Set 11 | newton
# Processing Record 11 of Set 11 | magole
# Processing Record 12 of Set 11 | padang
# Processing Record 13 of Set 11 | puri
# Processing Record 14 of Set 11 | ovre ardal
# Processing Record 15 of Set 11 | mayor pablo lagerenza
# Processing Record 16 of Set 11 | aleksandrov gay
# Processing Record 17 of Set 11 | tecoanapa
# Processing Record 18 of Set 11 | ketchikan
# Processing Record 19 of Set 11 | djambala
# Processing Record 20 of Set 11 | muisne
# Processing Record 21 of Set 11 | leca da palmeira
# Processing Record 22 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 23 of Set 11 | maniitsoq
# Processing Record 24 of Set 11 | cuyamel
# Processing Record 25 of Set 11 | dawlatabad
# Processing Record 26 of Set 11 | andenes
# Processing Record 27 of Set 11 | biak
# Processing Record 28 of Set 11 | sibolga
# Processing Record 29 of Set 11 | tautira
# Processing Record 30 of Set 11 | winnemucca
# Processing Record 31 of Set 11 | lefka
# Processing Record 32 of Set 11 | kharp
# Processing Record 33 of Set 11 | yumen
# Processing Record 34 of Set 11 | san ramon
# Processing Record 35 of Set 11 | saint-pierre
# Processing Record 36 of Set 11 | mackay
# Processing Record 37 of Set 11 | yomitan
# City not found. Skipping...
# Processing Record 38 of Set 11 | huanren
# Processing Record 39 of Set 11 | zyryanka
# Processing Record 40 of Set 11 | podgornoye
# Processing Record 41 of Set 11 | talnakh
# Processing Record 42 of Set 11 | ballina
# Processing Record 43 of Set 11 | kovernino
# Processing Record 44 of Set 11 | puerto parra
# Processing Record 45 of Set 11 | macheng
# Processing Record 46 of Set 11 | arkadak
# Processing Record 47 of Set 11 | oriximina
# Processing Record 48 of Set 11 | kupang
# Processing Record 49 of Set 11 | marawi
# Processing Record 50 of Set 11 | indergarh
# Processing Record 1 of Set 12 | dinghai
# Processing Record 2 of Set 12 | calama
# Processing Record 3 of Set 12 | naron
# Processing Record 4 of Set 12 | tilichiki
# Processing Record 5 of Set 12 | marovoay
# Processing Record 6 of Set 12 | wichita falls
# Processing Record 7 of Set 12 | hindaun
# Processing Record 8 of Set 12 | ewa beach
# Processing Record 9 of Set 12 | mwinilunga
# Processing Record 10 of Set 12 | mangrol
# Processing Record 11 of Set 12 | lorengau
# Processing Record 12 of Set 12 | yeniseysk
# Processing Record 13 of Set 12 | vardo
# Processing Record 14 of Set 12 | harper
# Processing Record 15 of Set 12 | port arthur
# Processing Record 16 of Set 12 | nhulunbuy
# Processing Record 17 of Set 12 | trairi
# Processing Record 18 of Set 12 | pimentel
# Processing Record 19 of Set 12 | sokoni
# Processing Record 20 of Set 12 | shimoda
# Processing Record 21 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 22 of Set 12 | finspang
# Processing Record 23 of Set 12 | kommunar
# Processing Record 24 of Set 12 | khorinsk
# Processing Record 25 of Set 12 | sigli
# Processing Record 26 of Set 12 | mareeba
# Processing Record 27 of Set 12 | coahuayana
# Processing Record 28 of Set 12 | biltine
# Processing Record 29 of Set 12 | talcahuano
# Processing Record 30 of Set 12 | pishin
# Processing Record 31 of Set 12 | hit
# Processing Record 32 of Set 12 | mindelo
# Processing Record 33 of Set 12 | toulepleu
# City not found. Skipping...
# Processing Record 34 of Set 12 | pahrump
# Processing Record 35 of Set 12 | tigil
# Processing Record 36 of Set 12 | pinsk
# Processing Record 37 of Set 12 | the valley
# Processing Record 38 of Set 12 | pochutla
# Processing Record 39 of Set 12 | jiwani
# Processing Record 40 of Set 12 | sorong
# Processing Record 41 of Set 12 | necochea
# Processing Record 42 of Set 12 | vestmannaeyjar
# Processing Record 43 of Set 12 | lewiston
# Processing Record 44 of Set 12 | celestun
# Processing Record 45 of Set 12 | mapiri
# Processing Record 46 of Set 12 | midland
# Processing Record 47 of Set 12 | limbang
# Processing Record 48 of Set 12 | vostok
# Processing Record 49 of Set 12 | la peca
# Processing Record 50 of Set 12 | kismayo
# Processing Record 1 of Set 13 | kenai
# Processing Record 2 of Set 13 | gurskoye
# City not found. Skipping...
# Processing Record 3 of Set 13 | verkhoyansk
# Processing Record 4 of Set 13 | armacao dos buzios
# City not found. Skipping...
# Processing Record 5 of Set 13 | kjollefjord
# Processing Record 6 of Set 13 | kimbe
# Processing Record 7 of Set 13 | honiara
# Processing Record 8 of Set 13 | laguna
# Processing Record 9 of Set 13 | vaitape
# Processing Record 10 of Set 13 | filingue
# Processing Record 11 of Set 13 | pundaguitan
# Processing Record 12 of Set 13 | antofagasta
# Processing Record 13 of Set 13 | orotukan
# Processing Record 14 of Set 13 | benjamin aceval
# Processing Record 15 of Set 13 | quatre cocos
# Processing Record 16 of Set 13 | nalut
# Processing Record 17 of Set 13 | morant bay
# Processing Record 18 of Set 13 | belyy yar
# Processing Record 19 of Set 13 | sao gabriel da cachoeira
# Processing Record 20 of Set 13 | melilla
# Processing Record 21 of Set 13 | hamilton
# Processing Record 22 of Set 13 | brae
# Processing Record 23 of Set 13 | eureka
# Processing Record 24 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 25 of Set 13 | palafrugell
# Processing Record 26 of Set 13 | burgeo
# Processing Record 27 of Set 13 | port-gentil
# Processing Record 28 of Set 13 | xichang
# Processing Record 29 of Set 13 | egvekinot
# Processing Record 30 of Set 13 | esperance
# Processing Record 31 of Set 13 | yelets
# Processing Record 32 of Set 13 | okitipupa
# Processing Record 33 of Set 13 | kaplice
# Processing Record 34 of Set 13 | lovington
# Processing Record 35 of Set 13 | ijsselstein
# Processing Record 36 of Set 13 | mascote
# Processing Record 37 of Set 13 | masjid tanah
# Processing Record 38 of Set 13 | bacuit
# City not found. Skipping...
# Processing Record 39 of Set 13 | nanakuli
# Processing Record 40 of Set 13 | usogorsk
# Processing Record 41 of Set 13 | gamba
# Processing Record 42 of Set 13 | papetoai
# Processing Record 43 of Set 13 | abiy adi
# City not found. Skipping...
# Processing Record 44 of Set 13 | moron
# Processing Record 45 of Set 13 | acapulco
# Processing Record 46 of Set 13 | nantucket
# Processing Record 47 of Set 13 | manakara
# Processing Record 48 of Set 13 | le port
# Processing Record 49 of Set 13 | bridlington
# Processing Record 50 of Set 13 | nabire
# Processing Record 1 of Set 14 | gigmoto
# Processing Record 2 of Set 14 | sangmelima
# Processing Record 3 of Set 14 | kushiro
# Processing Record 4 of Set 14 | nowy tomysl
# Processing Record 5 of Set 14 | hambantota
# Processing Record 6 of Set 14 | kahului
# Processing Record 7 of Set 14 | micheweni
# Processing Record 8 of Set 14 | zhigansk
# Processing Record 9 of Set 14 | urumqi
# Processing Record 10 of Set 14 | valparaiso
# Processing Record 11 of Set 14 | alice springs
# Processing Record 12 of Set 14 | jambi
# Processing Record 13 of Set 14 | umm durman
# City not found. Skipping...
# Processing Record 14 of Set 14 | madhubani
# Processing Record 15 of Set 14 | benemerito de las americas
# Processing Record 16 of Set 14 | scarborough
# Processing Record 17 of Set 14 | las palmas
# Processing Record 18 of Set 14 | sinnamary
# Processing Record 19 of Set 14 | tsubame
# Processing Record 20 of Set 14 | qianjiang
# Processing Record 21 of Set 14 | shingu
# Processing Record 22 of Set 14 | someshwar
# Processing Record 23 of Set 14 | caldwell
# Processing Record 24 of Set 14 | ocho rios
# Processing Record 25 of Set 14 | boende
# Processing Record 26 of Set 14 | osoyoos
# Processing Record 27 of Set 14 | poronaysk
# Processing Record 28 of Set 14 | athabasca
# Processing Record 29 of Set 14 | cururupu
# Processing Record 30 of Set 14 | monrovia
# Processing Record 31 of Set 14 | sault sainte marie
# Processing Record 32 of Set 14 | olafsvik
# Processing Record 33 of Set 14 | morsbach
# Processing Record 34 of Set 14 | rochester
# Processing Record 35 of Set 14 | san jose
# Processing Record 36 of Set 14 | leh
# Processing Record 37 of Set 14 | jiazi
# Processing Record 38 of Set 14 | invermere
# Processing Record 39 of Set 14 | firminopolis
# Processing Record 40 of Set 14 | ruteng
# Processing Record 41 of Set 14 | deming
# Processing Record 42 of Set 14 | indramayu
# Processing Record 43 of Set 14 | zaraza
# Processing Record 44 of Set 14 | souillac
# Processing Record 45 of Set 14 | monforte de lemos
# Processing Record 46 of Set 14 | krasnoborsk
# Processing Record 47 of Set 14 | arequipa
# Processing Record 48 of Set 14 | mbengwi
# Processing Record 49 of Set 14 | mitsamiouli
# Processing Record 50 of Set 14 | soto
# Processing Record 1 of Set 15 | san juan del parana
# Processing Record 2 of Set 15 | srednekolymsk
# Processing Record 3 of Set 15 | santa marta
# Processing Record 4 of Set 15 | qafsah
# City not found. Skipping...
# Processing Record 5 of Set 15 | kidal
# Processing Record 6 of Set 15 | pitangueiras
# Processing Record 7 of Set 15 | santander jimenez
# Processing Record 8 of Set 15 | sept-iles
# Processing Record 9 of Set 15 | fukue
# Processing Record 10 of Set 15 | kargasok
# Processing Record 11 of Set 15 | pinheiro machado
# Processing Record 12 of Set 15 | taunggyi
# Processing Record 13 of Set 15 | albury
# Processing Record 14 of Set 15 | luwuk
# Processing Record 15 of Set 15 | lahuachaca
# Processing Record 16 of Set 15 | nam tha
# City not found. Skipping...
# Processing Record 17 of Set 15 | hun
# Processing Record 18 of Set 15 | tiznit
# Processing Record 19 of Set 15 | acambay
# Processing Record 20 of Set 15 | beloha
# Processing Record 21 of Set 15 | sechelt
# Processing Record 22 of Set 15 | san juan
# Processing Record 23 of Set 15 | havre-saint-pierre
# Processing Record 24 of Set 15 | idah
# Processing Record 25 of Set 15 | constitucion
# Processing Record 26 of Set 15 | grootfontein
# Processing Record 27 of Set 15 | horsham
# Processing Record 28 of Set 15 | severnoye
# Processing Record 29 of Set 15 | pocatello
# Processing Record 30 of Set 15 | dunedin
# Processing Record 31 of Set 15 | wanaka
# Processing Record 32 of Set 15 | westport
# Processing Record 33 of Set 15 | uyuni
# Processing Record 34 of Set 15 | parakou
# Processing Record 35 of Set 15 | talavera de la reina
# Processing Record 36 of Set 15 | adilcevaz
# Processing Record 37 of Set 15 | bom jesus
# Processing Record 38 of Set 15 | staryy nadym
# Processing Record 39 of Set 15 | maputo
# Processing Record 40 of Set 15 | canberra
# Processing Record 41 of Set 15 | yefira
# City not found. Skipping...
# Processing Record 42 of Set 15 | burnie
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Luderitz -26.6481   15.1594     65.12        62           0
# 1            Rikitea -23.1203 -134.9692     75.99        54          99
# 2             Barrow  71.2906 -156.7887    -11.18        77           0
# 3       Longyearbyen  78.2186   15.6401      1.24        60          20
# 4            Melfort  52.8667 -104.6177     26.73        80         100
# 5          Grindavik  63.8424  -22.4338     46.35        81          40
# 6               Kosa  59.9445   54.9977      9.63        97          47
# 7          Busselton -33.6500  115.3333     69.57        82         100
# 8      Leningradskiy  69.3833  178.4167     -0.33        96         100
# 9  Sao Joao Da Barra -21.6403  -41.0511     80.69        75          57
#
#    Wind Speed Country Current Description
# 0       21.43      NA           clear sky
# 1       15.86      PF     overcast clouds
# 2       19.57      US           clear sky
# 3        8.05      SJ          few clouds
# 4       17.69      CA     overcast clouds
# 5       12.66      IS    scattered clouds
# 6        1.03      RU    scattered clouds
# 7        6.96      AU     overcast clouds
# 8        5.79      RU     overcast clouds
# 9        9.93      BR       broken clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0           Luderitz      NA -26.6481   15.1594     65.12        62
# 1            Rikitea      PF -23.1203 -134.9692     75.99        54
# 2             Barrow      US  71.2906 -156.7887    -11.18        77
# 3       Longyearbyen      SJ  78.2186   15.6401      1.24        60
# 4            Melfort      CA  52.8667 -104.6177     26.73        80
# 5          Grindavik      IS  63.8424  -22.4338     46.35        81
# 6               Kosa      RU  59.9445   54.9977      9.63        97
# 7          Busselton      AU -33.6500  115.3333     69.57        82
# 8      Leningradskiy      RU  69.3833  178.4167     -0.33        96
# 9  Sao Joao Da Barra      BR -21.6403  -41.0511     80.69        75
#
#    Cloudiness  Wind Speed Current Description
# 0           0       21.43           clear sky
# 1          99       15.86     overcast clouds
# 2           0       19.57           clear sky
# 3          20        8.05          few clouds
# 4         100       17.69     overcast clouds
# 5          40       12.66    scattered clouds
# 6          47        1.03    scattered clouds
# 7         100        6.96     overcast clouds
# 8         100        5.79     overcast clouds
# 9          57        9.93       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
